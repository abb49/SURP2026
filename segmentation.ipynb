# %%
import os
import json
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

with open('C:\Users/buker/Downloads/SURP2026/via_project_24Apr2025_15h0m_json (5) (1).json', 'r') as file
    segmentation = json.load(file)

print(json.dumps(segmentation, indent = 4))
